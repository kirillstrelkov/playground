# %% [markdown]
# # Most suitable car between all cars

# %%
from find_best_car import (
    Column, 
    get_scored_df,
    _get_fixed_column_name,
)


df = get_scored_df(de_discount=True, feature_file_name="feature.csv")
# Out:
# /home/kirill/workspace/github/playground/auto/adac/best_car/find_best_car.py:329: DtypeWarning: Columns (231,232,233,234) have mixed types.Specify dtype option on import or set low_memory=False.
#   df = get_cars()
# 2022-03-21 00:19:00.896 | WARNING  | find_best_car:get_scored_df:385 - Duplicates:
#         id                                                                       name
# 0   321858                               Ford Fiesta 1.0 EcoBoost Titanium (ab 03/22)
# 1   321862                  Ford Fiesta 1.0 EcoBoost Hybrid Cool & Connect (ab 03/22)
# 2   319419                               Renault Captur TCe 140 GPF Intens (ab 01/21)
# 3   316455           KIA Stonic 1.0 T-GDI 120 48V-Mild-Hybrid GT Line DCT7 (ab 10/20)
# 4   318695                                Peugeot 2008 1.2 PureTech 130 GT (ab 01/21)
# 5   323490  Opel Astra Sports Tourer 1.2 Turbo Business Elegance Automatik (ab 06/22)
# 6   322582            Suzuki Vitara 1.5 Dualjet Hybrid Comfort ALLGRIP AGS (ab 03/22)
# 7   314892                                        Audi Q2 35 TFSI advanced (ab 10/20)
# 8   315738                                                BMW 118i M Sport (ab 11/20)
# 9   323592                         MINI 3-Türer Cooper SE Resolute Edition (ab 03/22)
# 10  315820                                BMW 216i Gran Tourer Luxury Line (ab 11/20)
# 11  319035                      Skoda Octavia 2.0 TDI SCR Ambition 4x4 DSG (ab 01/21)
# 12  315521                   VW Passat Variant 1.5 TSI OPF Conceptline DSG (ab 09/20)
# 13  310090                                  BMW 118d Sport Line Steptronic (ab 03/20)
# 14  316071                   Peugeot 5008 1.5 BlueHDi 130 Active Pack EAT8 (ab 01/21)
# 15  314033         Opel Insignia Grand Sport 1.5 Diesel Elegance Automatik (ab 07/20)
# 16  310243                                     BMW X1 sDrive18d Sport Line (ab 03/20)
# 17  322937             Volvo XC40 Recharge Plug-in Hybrid T4 Essential DKG (ab 11/21)
# 18  316074                           Peugeot 5008 1.6 PureTech 180 GT EAT8 (ab 01/21)
# 19  315584                               Audi A5 Sportback 35 TDI S tronic (ab 09/20)
# 20  315684                       Ford Kuga 2.5 Plugin-Hybrid ST-Line X CVT (ab 09/20)
# 21  315591                                   Audi A5 Coupé 35 TDI S tronic (ab 09/20)
# 22  321723                         BMW i3s (120 Ah) Edition Unique Forever (ab 11/21)
# 23  318777                                      Audi Q3 45 TFSI e S tronic (ab 01/21)
# /home/kirill/workspace/github/playground/auto/adac/best_car/find_best_car.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_electric[scaled_col_name] = __apply_scaler_for_columns(
# /home/kirill/workspace/github/playground/auto/adac/best_car/find_best_car.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_non_electric[scaled_col_name] = __apply_scaler_for_columns(

# %%
imprezas = df[df[Column.NAME].str.contains('Subaru Impreza 2.0i Exclusive')]

top_impreza = imprezas.iloc[0]
impreza_euro_per_score = top_impreza[Column.EURO_PER_SCORE]
impreza_total_score = top_impreza[Column.TOTAL_SCORE]

# imprezas
top_impreza
# Out:
# name                                             Subaru Impreza 2.0i Exclusive Lineartronic (01...
# url                                              https://www.adac.de/rund-ums-fahrzeug/autokata...
# id                                                                                          283761
# image                                            https://assets.adac.de/image/upload/ar_16:9,c_...
# processed date                                                          2022-03-07 03:31:31.270654
#                                                                        ...
# Airbag Fahrer|fixed|scaled|weighted                                                            1.0
# Antriebsschlupfregelung|fixed|scaled|weighted                                                  1.0
# Fahrdynamikregelung|fixed|scaled|weighted                                                      1.0
# Total Score                                                                             430.461789
# Euro per score                                                                           66.161505
# Name: 1297, Length: 572, dtype: object

# %% [markdown]
# ### Better in score

# %%
FIXED_PRICE_COLUMN = _get_fixed_column_name(Column.PRICE)
VIEW_COLUMNS = [Column.NAME, FIXED_PRICE_COLUMN, Column.TOTAL_SCORE, Column.EURO_PER_SCORE]
VIEW_LIMIT = 40

df[df[Column.TOTAL_SCORE] > impreza_total_score][VIEW_COLUMNS].reset_index(drop=True).head(VIEW_LIMIT)
# Out:
#                                                  name  Grundpreis|fixed  \
# 0                            Tesla Model 3 (ab 02/22)           37560.0
# 1   Hyundai IONIQ Elektro (38,3 kWh) Prime-Paket (...           33650.0
# 2                   Mazda MX-30 e-SKYACTIV (ab 09/20)           25490.0
# 3                       KIA EV6 (77,4 kWh) (ab 10/21)           39990.0
# 4               Nissan Leaf (40 kWh) Tekna (ab 05/19)           28050.0
# 5               KIA e-Niro (64 kWh) Spirit (ab 01/20)           36790.0
# 6                         KIA EV6 (58 kWh) (ab 10/21)           35990.0
# 7            Nissan Leaf (62 kWh) e+ Tekna (ab 05/19)           33050.0
# 8          Nissan Leaf (40 kWh) N-CONNECTA (ab 05/19)           25900.0
# 9                       Citroen e-C4 Shine (ab 12/20)           28340.0
# 10      Nissan Leaf (62 kWh) e+ N-CONNECTA (ab 05/19)           30900.0
# 11     Hyundai Kona Elektro (64 kWh) Trend (ab 01/21)           35550.0
# 12                   Opel Corsa-e Elegance (ab 05/20)           23895.0
# 13   Hyundai Kona Elektro (39,2 kWh) Trend (ab 02/21)           29950.0
# 14      Ford Mustang Mach-E Standard Range (ab 01/21)           39000.0
# 15                    Opel Corsa-e GS Line (ab 05/20)           24745.0
# 16  Hyundai IONIQ Elektro (38,3 kWh) Style-Paket (...           31300.0
# 17                     CUPRA Born (58 kWh) (ab 11/21)           28220.0
# 18  KIA Ceed Sportswagon 1.6 GDI Plug-in Hybrid Sp...           29440.0
# 19              KIA e-Niro (64 kWh) Vision (ab 01/20)           33790.0
# 20                   Opel Mokka-e Elegance (ab 01/21)           28300.0
# 21         Skoda Octavia RS 1.4 TSI iV DSG (ab 09/20)           36610.0
# 22                    Opel Mokka-e GS Line (ab 01/21)           29580.0
# 23   Skoda Octavia Combi RS 1.4 TSI iV DSG (ab 09/20)           37310.0
# 24          KIA Ceed 1.5 T-GDI Spirit DCT7 (ab 10/21)           30130.0
# 25  KIA Ceed Sportswagon 1.5 T-GDI Spirit DCT7 (ab...           31530.0
# 26                         VW Golf GTE DSG (ab 08/20)           35190.0
# 27  VW Tiguan 1.4 eHybrid OPF Elegance DSG (ab 11/20)           39350.0
# 28         KIA Ceed 1.5 T-GDI GT Line DCT7 (ab 10/21)           31030.0
# 29  KIA Ceed Sportswagon 1.5 T-GDI GT Line DCT7 (a...           32430.0
# 30          Nissan Leaf (62 kWh) e+ Acenta (ab 05/20)           28550.0
# 31  Hyundai IONIQ PlugIn-Hybrid Prime-Paket (ab 07...           32350.0
# 32      Skoda Octavia 1.4 TSI iV Style DSG (ab 09/20)           32640.0
# 33  Skoda Octavia Combi 1.4 TSI iV Style DSG (ab 0...           33340.0
# 34           VW Golf 1.4 eHybrid Style DSG (ab 08/20)           33235.0
# 35  KIA XCeed 1.6 GDI Plug-in-Hybrid Platinum DCT6...           36140.0
# 36    VW Tiguan 1.4 eHybrid OPF R-Line DSG (ab 11/20)           41340.0
# 37                 VW ID.5 Pro Performance (ab 04/22)           38550.0
# 38      KIA ProCeed 1.5 T-GDI GT Line DCT7 (ab 10/21)           33350.0
# 39  Hyundai Tucson 1.6 T-GDI Plug-in-Hybrid Prime ...           41850.0
#
#     Total Score  Euro per score
# 0    524.142428       71.659911
# 1    521.203721       64.562087
# 2    518.874644       49.125546
# 3    517.758213       77.236824
# 4    516.109136       54.348970
# 5    515.553804       71.360156
# 6    515.060360       69.875305
# 7    513.976320       64.302573
# 8    513.057912       50.481631
# 9    511.846450       55.368168
# 10   510.925096       60.478532
# 11   508.491911       69.912617
# 12   506.290691       47.196206
# 13   505.572898       59.239726
# 14   505.262596       77.187586
# 15   503.781753       49.118492
# 16   503.697878       62.140425
# 17   503.613994       56.034980
# 18   502.614432       58.573726
# 19   502.575161       67.233725
# 20   501.959110       56.379094
# 21   499.783083       73.251779
# 22   499.420619       59.228632
# 23   498.277342       74.877978
# 24   497.329490       60.583578
# 25   496.961408       63.445570
# 26   496.861522       70.824563
# 27   496.681582       79.225809
# 28   494.601177       62.737416
# 29   494.243973       65.615368
# 30   494.201822       57.769921
# 31   492.599932       65.671954
# 32   491.602488       66.395107
# 33   490.798078       67.930176
# 34   490.182762       67.801242
# 35   489.541892       73.824121
# 36   489.300660       84.487930
# 37   488.401090       78.931028
# 38   488.194946       68.312874
# 39   488.122282       85.736713

# %% [markdown]
# ### Better in euro per score

# %%
df[df[Column.EURO_PER_SCORE] < impreza_euro_per_score][VIEW_COLUMNS].reset_index(drop=True).head(VIEW_LIMIT)
# Out:
#                                                  name  Grundpreis|fixed  \
# 0   Hyundai IONIQ Elektro (38,3 kWh) Prime-Paket (...           33650.0
# 1                   Mazda MX-30 e-SKYACTIV (ab 09/20)           25490.0
# 2               Nissan Leaf (40 kWh) Tekna (ab 05/19)           28050.0
# 3            Nissan Leaf (62 kWh) e+ Tekna (ab 05/19)           33050.0
# 4          Nissan Leaf (40 kWh) N-CONNECTA (ab 05/19)           25900.0
# 5                       Citroen e-C4 Shine (ab 12/20)           28340.0
# 6       Nissan Leaf (62 kWh) e+ N-CONNECTA (ab 05/19)           30900.0
# 7                    Opel Corsa-e Elegance (ab 05/20)           23895.0
# 8    Hyundai Kona Elektro (39,2 kWh) Trend (ab 02/21)           29950.0
# 9                     Opel Corsa-e GS Line (ab 05/20)           24745.0
# 10  Hyundai IONIQ Elektro (38,3 kWh) Style-Paket (...           31300.0
# 11                     CUPRA Born (58 kWh) (ab 11/21)           28220.0
# 12  KIA Ceed Sportswagon 1.6 GDI Plug-in Hybrid Sp...           29440.0
# 13                   Opel Mokka-e Elegance (ab 01/21)           28300.0
# 14                    Opel Mokka-e GS Line (ab 01/21)           29580.0
# 15          KIA Ceed 1.5 T-GDI Spirit DCT7 (ab 10/21)           30130.0
# 16  KIA Ceed Sportswagon 1.5 T-GDI Spirit DCT7 (ab...           31530.0
# 17         KIA Ceed 1.5 T-GDI GT Line DCT7 (ab 10/21)           31030.0
# 18  KIA Ceed Sportswagon 1.5 T-GDI GT Line DCT7 (a...           32430.0
# 19          Nissan Leaf (62 kWh) e+ Acenta (ab 05/20)           28550.0
# 20  Hyundai IONIQ PlugIn-Hybrid Prime-Paket (ab 07...           32350.0
# 21   MINI 3-Türer Cooper SE Essential Trim (ab 03/21)           23500.0
# 22     MINI 3-Türer Cooper SE Classic Trim (ab 03/21)           24900.0
# 23  Hyundai i20 1.0 T-GDI 48V-Hybrid Prime DCT (ab...           24690.0
# 24  Hyundai i20 1.0 T-GDI 48V-Hybrid Prime DCT (ab...           23890.0
# 25    MINI 3-Türer Cooper SE Electric Trim (ab 03/21)           26900.0
# 26  MINI 3-Türer Cooper SE Resolute Edition (ab 03...           27000.0
# 27  MINI 3-Türer Cooper SE Mini Yours Trim (ab 03/21)           27300.0
# 28            KIA e-Niro (39,2 kWh) Vision (ab 01/20)           29290.0
# 29                  Citroen e-C4 Feel Pack (ab 12/20)           26940.0
# 30   Skoda Octavia 1.0 TSI e-TEC Style DSG (ab 10/20)           31290.0
# 31                   Citroen e-C4 C-Series (ab 10/21)           27190.0
# 32  Hyundai IONIQ PlugIn-Hybrid Style-Paket (ab 07...           29850.0
# 33             Nissan Leaf (40 kWh) Acenta (ab 01/21)           23400.0
# 34                       Skoda Enyaq iV 60 (ab 04/21)           30650.0
# 35                    Opel Mokka-e Edition (ab 01/21)           25110.0
# 36        VW ID.3 Pro Performance (58 kWh) (ab 05/21)           27960.0
# 37           VW Polo 1.0 TSI OPF Style DSG (ab 09/21)           25170.0
# 38           VW Polo 1.0 TSI OPF Style DSG (ab 09/21)           26510.0
# 39  Mazda 3 e-SKYACTIV-X 2.0 M Hybrid Selection SK...           30890.0
#
#     Total Score  Euro per score
# 0    521.203721       64.562087
# 1    518.874644       49.125546
# 2    516.109136       54.348970
# 3    513.976320       64.302573
# 4    513.057912       50.481631
# 5    511.846450       55.368168
# 6    510.925096       60.478532
# 7    506.290691       47.196206
# 8    505.572898       59.239726
# 9    503.781753       49.118492
# 10   503.697878       62.140425
# 11   503.613994       56.034980
# 12   502.614432       58.573726
# 13   501.959110       56.379094
# 14   499.420619       59.228632
# 15   497.329490       60.583578
# 16   496.961408       63.445570
# 17   494.601177       62.737416
# 18   494.243973       65.615368
# 19   494.201822       57.769921
# 20   492.599932       65.671954
# 21   487.652309       48.190072
# 22   484.907163       51.350035
# 23   482.060435       51.217644
# 24   480.593725       49.709346
# 25   480.203701       56.017894
# 26   480.021045       56.247534
# 27   479.410423       56.944945
# 28   478.848208       61.167609
# 29   478.472811       56.304140
# 30   477.546373       65.522433
# 31   477.422344       56.951670
# 32   477.228979       62.548591
# 33   477.056357       49.050808
# 34   475.695922       64.431917
# 35   474.303948       52.940736
# 36   474.264554       58.954437
# 37   472.830334       53.232625
# 38   472.770825       56.073680
# 39   471.847469       65.466071

# %% [markdown]
# ### Better in everything

# %%
d = df[(df[Column.TOTAL_SCORE] >= impreza_total_score) & (df[Column.EURO_PER_SCORE] <= impreza_euro_per_score)]
d[VIEW_COLUMNS].reset_index(drop=True).head(VIEW_LIMIT)
# Out:
#                                                  name  Grundpreis|fixed  \
# 0   Hyundai IONIQ Elektro (38,3 kWh) Prime-Paket (...           33650.0
# 1                   Mazda MX-30 e-SKYACTIV (ab 09/20)           25490.0
# 2               Nissan Leaf (40 kWh) Tekna (ab 05/19)           28050.0
# 3            Nissan Leaf (62 kWh) e+ Tekna (ab 05/19)           33050.0
# 4          Nissan Leaf (40 kWh) N-CONNECTA (ab 05/19)           25900.0
# 5                       Citroen e-C4 Shine (ab 12/20)           28340.0
# 6       Nissan Leaf (62 kWh) e+ N-CONNECTA (ab 05/19)           30900.0
# 7                    Opel Corsa-e Elegance (ab 05/20)           23895.0
# 8    Hyundai Kona Elektro (39,2 kWh) Trend (ab 02/21)           29950.0
# 9                     Opel Corsa-e GS Line (ab 05/20)           24745.0
# 10  Hyundai IONIQ Elektro (38,3 kWh) Style-Paket (...           31300.0
# 11                     CUPRA Born (58 kWh) (ab 11/21)           28220.0
# 12  KIA Ceed Sportswagon 1.6 GDI Plug-in Hybrid Sp...           29440.0
# 13                   Opel Mokka-e Elegance (ab 01/21)           28300.0
# 14                    Opel Mokka-e GS Line (ab 01/21)           29580.0
# 15          KIA Ceed 1.5 T-GDI Spirit DCT7 (ab 10/21)           30130.0
# 16  KIA Ceed Sportswagon 1.5 T-GDI Spirit DCT7 (ab...           31530.0
# 17         KIA Ceed 1.5 T-GDI GT Line DCT7 (ab 10/21)           31030.0
# 18  KIA Ceed Sportswagon 1.5 T-GDI GT Line DCT7 (a...           32430.0
# 19          Nissan Leaf (62 kWh) e+ Acenta (ab 05/20)           28550.0
# 20  Hyundai IONIQ PlugIn-Hybrid Prime-Paket (ab 07...           32350.0
# 21   MINI 3-Türer Cooper SE Essential Trim (ab 03/21)           23500.0
# 22     MINI 3-Türer Cooper SE Classic Trim (ab 03/21)           24900.0
# 23  Hyundai i20 1.0 T-GDI 48V-Hybrid Prime DCT (ab...           24690.0
# 24  Hyundai i20 1.0 T-GDI 48V-Hybrid Prime DCT (ab...           23890.0
# 25    MINI 3-Türer Cooper SE Electric Trim (ab 03/21)           26900.0
# 26  MINI 3-Türer Cooper SE Resolute Edition (ab 03...           27000.0
# 27  MINI 3-Türer Cooper SE Mini Yours Trim (ab 03/21)           27300.0
# 28            KIA e-Niro (39,2 kWh) Vision (ab 01/20)           29290.0
# 29                  Citroen e-C4 Feel Pack (ab 12/20)           26940.0
# 30   Skoda Octavia 1.0 TSI e-TEC Style DSG (ab 10/20)           31290.0
# 31                   Citroen e-C4 C-Series (ab 10/21)           27190.0
# 32  Hyundai IONIQ PlugIn-Hybrid Style-Paket (ab 07...           29850.0
# 33             Nissan Leaf (40 kWh) Acenta (ab 01/21)           23400.0
# 34                       Skoda Enyaq iV 60 (ab 04/21)           30650.0
# 35                    Opel Mokka-e Edition (ab 01/21)           25110.0
# 36        VW ID.3 Pro Performance (58 kWh) (ab 05/21)           27960.0
# 37           VW Polo 1.0 TSI OPF Style DSG (ab 09/21)           25170.0
# 38           VW Polo 1.0 TSI OPF Style DSG (ab 09/21)           26510.0
# 39  Mazda 3 e-SKYACTIV-X 2.0 M Hybrid Selection SK...           30890.0
#
#     Total Score  Euro per score
# 0    521.203721       64.562087
# 1    518.874644       49.125546
# 2    516.109136       54.348970
# 3    513.976320       64.302573
# 4    513.057912       50.481631
# 5    511.846450       55.368168
# 6    510.925096       60.478532
# 7    506.290691       47.196206
# 8    505.572898       59.239726
# 9    503.781753       49.118492
# 10   503.697878       62.140425
# 11   503.613994       56.034980
# 12   502.614432       58.573726
# 13   501.959110       56.379094
# 14   499.420619       59.228632
# 15   497.329490       60.583578
# 16   496.961408       63.445570
# 17   494.601177       62.737416
# 18   494.243973       65.615368
# 19   494.201822       57.769921
# 20   492.599932       65.671954
# 21   487.652309       48.190072
# 22   484.907163       51.350035
# 23   482.060435       51.217644
# 24   480.593725       49.709346
# 25   480.203701       56.017894
# 26   480.021045       56.247534
# 27   479.410423       56.944945
# 28   478.848208       61.167609
# 29   478.472811       56.304140
# 30   477.546373       65.522433
# 31   477.422344       56.951670
# 32   477.228979       62.548591
# 33   477.056357       49.050808
# 34   475.695922       64.431917
# 35   474.303948       52.940736
# 36   474.264554       58.954437
# 37   472.830334       53.232625
# 38   472.770825       56.073680
# 39   471.847469       65.466071

# %%
### Better in everything and cheaper

# %%
d = df[
    (df[Column.TOTAL_SCORE] >= impreza_total_score) & 
    (df[Column.EURO_PER_SCORE] <= impreza_euro_per_score) &
    (df[FIXED_PRICE_COLUMN] <= top_impreza[FIXED_PRICE_COLUMN])
]
d[VIEW_COLUMNS].reset_index(drop=True).head(VIEW_LIMIT)
# Out:
#                                                  name  Grundpreis|fixed  \
# 0                   Mazda MX-30 e-SKYACTIV (ab 09/20)           25490.0
# 1               Nissan Leaf (40 kWh) Tekna (ab 05/19)           28050.0
# 2          Nissan Leaf (40 kWh) N-CONNECTA (ab 05/19)           25900.0
# 3                       Citroen e-C4 Shine (ab 12/20)           28340.0
# 4                    Opel Corsa-e Elegance (ab 05/20)           23895.0
# 5                     Opel Corsa-e GS Line (ab 05/20)           24745.0
# 6                      CUPRA Born (58 kWh) (ab 11/21)           28220.0
# 7                    Opel Mokka-e Elegance (ab 01/21)           28300.0
# 8    MINI 3-Türer Cooper SE Essential Trim (ab 03/21)           23500.0
# 9      MINI 3-Türer Cooper SE Classic Trim (ab 03/21)           24900.0
# 10  Hyundai i20 1.0 T-GDI 48V-Hybrid Prime DCT (ab...           24690.0
# 11  Hyundai i20 1.0 T-GDI 48V-Hybrid Prime DCT (ab...           23890.0
# 12    MINI 3-Türer Cooper SE Electric Trim (ab 03/21)           26900.0
# 13  MINI 3-Türer Cooper SE Resolute Edition (ab 03...           27000.0
# 14  MINI 3-Türer Cooper SE Mini Yours Trim (ab 03/21)           27300.0
# 15                  Citroen e-C4 Feel Pack (ab 12/20)           26940.0
# 16                   Citroen e-C4 C-Series (ab 10/21)           27190.0
# 17             Nissan Leaf (40 kWh) Acenta (ab 01/21)           23400.0
# 18                    Opel Mokka-e Edition (ab 01/21)           25110.0
# 19        VW ID.3 Pro Performance (58 kWh) (ab 05/21)           27960.0
# 20           VW Polo 1.0 TSI OPF Style DSG (ab 09/21)           25170.0
# 21           VW Polo 1.0 TSI OPF Style DSG (ab 09/21)           26510.0
# 22  Hyundai Bayon 1.0 T-GDI 48-Volt-Mildhybrid Pri...           26590.0
# 23          VW Polo 1.0 TSI OPF R-Line DSG (ab 09/21)           26215.0
# 24          VW Polo 1.0 TSI OPF R-Line DSG (ab 09/21)           27555.0
# 25  Hyundai Bayon 1.0 T-GDI 48-Volt-Mildhybrid Pri...           25790.0
# 26  Opel Corsa 1.2 DI Turbo GS Line Automatik (ab ...           25930.0
# 27  Mazda 3 e-SKYACTIV-G 2.0 M Hybrid Selection SK...           28390.0
# 28  Opel Corsa 1.2 DI Turbo Elegance Automatik (ab...           23520.0
# 29               VW Polo 1.0 TSI OPF Style (ab 09/21)           23515.0
# 30  Hyundai Bayon 1.0 T-GDI 48-Volt-Mildhybrid Pri...           24290.0
# 31            VW Polo 1.0 TSI OPF Life DSG (ab 09/21)           22775.0
# 32  Hyundai Bayon 1.0 T-GDI 48-Volt-Mildhybrid Pri...           25090.0
# 33  Mazda 3 e-SKYACTIV-G 2.0 M Hybrid 150 SKYACTIV...           27590.0
# 34            VW Polo 1.0 TSI OPF Life DSG (ab 09/21)           24115.0
# 35                   VW Polo 1.0 TGI Style (ab 09/21)           25775.0
# 36  Mazda 3 e-SKYACTIV-G 2.0 M Hybrid SKYACTIV-Dri...           26590.0
# 37              VW Polo 1.0 TSI OPF R-Line (ab 09/21)           24560.0
# 38                    Opel Corsa-e Edition (ab 03/20)           22150.0
# 39       Toyota Yaris 1.5 Hybrid Style CVT (ab 09/20)           26790.0
#
#     Total Score  Euro per score
# 0    518.874644       49.125546
# 1    516.109136       54.348970
# 2    513.057912       50.481631
# 3    511.846450       55.368168
# 4    506.290691       47.196206
# 5    503.781753       49.118492
# 6    503.613994       56.034980
# 7    501.959110       56.379094
# 8    487.652309       48.190072
# 9    484.907163       51.350035
# 10   482.060435       51.217644
# 11   480.593725       49.709346
# 12   480.203701       56.017894
# 13   480.021045       56.247534
# 14   479.410423       56.944945
# 15   478.472811       56.304140
# 16   477.422344       56.951670
# 17   477.056357       49.050808
# 18   474.303948       52.940736
# 19   474.264554       58.954437
# 20   472.830334       53.232625
# 21   472.770825       56.073680
# 22   470.738481       56.485716
# 23   470.431794       55.725400
# 24   470.414471       58.576004
# 25   469.788230       54.897076
# 26   469.397141       55.241069
# 27   469.250324       60.500757
# 28   468.784716       50.172284
# 29   466.653311       50.390728
# 30   465.879939       52.137896
# 31   465.267861       48.950297
# 32   465.261494       53.926663
# 33   465.220505       59.305211
# 34   465.208353       51.836988
# 35   465.090260       55.419350
# 36   464.891735       57.196113
# 37   464.326833       52.893777
# 38   464.105318       47.726236
# 39   462.897836       57.874541
