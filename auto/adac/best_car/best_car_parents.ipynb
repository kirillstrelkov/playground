# %%
from find_best_car import (
    Column, 
    get_scored_df,
    _get_fixed_column_name,
)

df = get_scored_df(feature_file_name="feature_parents.csv")
# Out:
# /home/kirill/workspace/github/playground/auto/adac/best_car/find_best_car.py:353: DtypeWarning: Columns (238,239,240) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path)
# 2023-03-19 12:46:21.121 | WARNING  | find_best_car:get_scored_df:415 - Duplicates:
#         id                                                                                               name
# 0   325888                         Dacia Sandero Stepway TCe 100 ECO-G Expression (Autogasbetrieb) (ab 07/22)
# 1   325890                          Dacia Sandero Stepway TCe 100 ECO-G Expression (Benzinbetrieb) (ab 07/22)
# 2   322610                                                 Dacia Jogger TCe 110 Extreme (7-Sitzer) (ab 03/22)
# 3   325569                                            Renault Arkana Mild Hybrid 140 Equilibre EDC (ab 06/22)
# 4   317862                                                               Audi A3 Sportback 35 TFSI (ab 11/20)
# 5   321830                                                           Ford Fiesta ST 1.5 EcoBoost X (ab 03/22)
# 6   318876                                                   Hyundai Kona 1.6 GDI Hybrid Trend DCT (ab 01/21)
# 7   324865                                                       Renault Mégane TCe 140 GPF Techno (ab 04/22)
# 8   319820                           Ford Puma 1.0 EcoBoost Hybrid Titanium X PowerShift Automatik (ab 03/21)
# 9   319771                                                       Audi A3 Sportback 35 TDI advanced (ab 01/21)
# 10  320481                                                            Lynk & Co 01 1.5TD PHEV DCTH (ab 04/21)
# 11  324780                                     VinFast VF 8 Eco (87,7 kWh) AWD (zzgl. Battermiete) (ab 04/23)
# 12  327298                               Abarth 500e Cabrio (42 kWh) Scorpionissima Launch Edition (ab 04/23)
# 13  324897                                           BMW 116d Edition Colorvision Steptronic (DKG) (ab 07/22)
# 14  321101                               DS Automobiles DS 4 E-Tense 225 Cross Trocadero Automatik (ab 10/21)
# 15  313479                                                      Audi A5 Sportback 40 TFSI S tronic (ab 07/20)
# 16  313488                                                          Audi A5 Coupé 40 TFSI S tronic (ab 07/20)
# 17  325251                                                  BMW 220d Coupé M Sportpaket Steptronic (ab 07/22)
# 18  326765          Alfa Romeo Tonale 1.3 T Multiair Plug-in Hybrid Edizione Speciale Q4 Automatik (ab 06/23)
# 19  312689                                                               BMW 420i Coupé Steptronic (ab 10/20)
# 20  326672  MINI Clubman John Cooper Works Untold Edition inkl. Paket Premium Plus ALL4 Steptronic (ab 07/22)
# 21  316415                                                   Jaguar XE P250 R-Dynamic SE Automatik (ab 01/21)
# 22  312694                                                        BMW 420d Coupé xDrive Steptronic (ab 10/20)
# /home/kirill/workspace/github/playground/auto/adac/best_car/find_best_car.py:523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter[scaled_col_name] = __apply_scaler_for_columns(
# /home/kirill/workspace/github/playground/auto/adac/best_car/find_best_car.py:523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter[scaled_col_name] = __apply_scaler_for_columns(

# %% [markdown]
# # Best cars by score

# %%
FIXED_PRICE_COLUMN = _get_fixed_column_name(Column.PRICE)
VIEW_COLUMNS = [Column.NAME, FIXED_PRICE_COLUMN, Column.TOTAL_SCORE, Column.EURO_PER_SCORE]
VIEW_LIMIT = 10

df[VIEW_COLUMNS].head(VIEW_LIMIT)
# Out:
#                                                 name  Grundpreis|fixed  \
# 0  Hyundai IONIQ 6 (53 kWh) TECHNIQ-Paket 2WD (ab...           52100.0
# 1  Hyundai IONIQ 5 (58 kWh) DYNAMIQ-Paket 2WD (ab...           50800.0
# 2  VinFast VF 8 Eco (82 kWh) AWD (zzgl. Battermie...           45700.0
# 3  VinFast VF 8 Eco (87,7 kWh) AWD (zzgl. Batterm...           46000.0
# 4  Hyundai IONIQ 5 (77,4 kWh) DYNAMIQ-Paket 2WD (...           54800.0
# 5  Hyundai IONIQ 5 (58 kWh) TECHNIQ-Paket 2WD (ab...           53200.0
# 6          KIA EV6 (77,4 kWh) GT Line 4WD (ab 10/21)           60890.0
# 7  Hyundai IONIQ 6 (53 kWh) DYNAMIC-Paket 2WD (ab...           49000.0
# 8  Hyundai IONIQ 6 (77,4 kWh) UNIQ-Paket 2WD (ab ...           60200.0
# 9                 Subaru Solterra Comfort (ab 10/22)           57490.0
#
#    Total Score  Euro per score
# 0   198.483868      262.489846
# 1   198.475303      255.951241
# 2   198.130378      230.656199
# 3   198.104653      232.200503
# 4   197.339350      277.694236
# 5   197.212145      269.760263
# 6   197.197424      308.776853
# 7   197.143931      248.549371
# 8   196.964940      305.638150
# 9   196.641411      292.359579

# %% [markdown]
# # Best cars by euro per score

# %%
df[VIEW_COLUMNS].sort_values([Column.EURO_PER_SCORE, Column.TOTAL_SCORE]).head(VIEW_LIMIT)
# Out:
#                                                    name  Grundpreis|fixed  \
# 4002          Dacia Sandero SCe 65 Essential (ab 01/21)           10750.0
# 3520         Dacia Sandero TCe 90 Expression (ab 06/22)           13750.0
# 3963          Dacia Sandero TCe 90 Essential (ab 01/21)           12350.0
# 3550  Dacia Sandero TCe 100 ECO-G Expression (Benzin...           14350.0
# 3577  Dacia Sandero TCe 100 ECO-G Expression (Autoga...           14350.0
# 3977  Dacia Sandero TCe 100 ECO-G Essential (Benzinb...           12950.0
# 3988  Dacia Sandero TCe 100 ECO-G Essential (Autogas...           12950.0
# 3498     Dacia Sandero TCe 90 Expression CVT (ab 06/22)           15050.0
# 3719                  Hyundai i10 1.0 Select (ab 09/20)           14785.0
# 3255            Hyundai i10 1.0 Connect & Go (ab 06/22)           15800.0
#
#       Total Score  Euro per score
# 4002   128.427252       83.704976
# 3520   146.307996       93.979826
# 3963   130.403963       94.705711
# 3550   145.711335       98.482387
# 3577   145.134220       98.873994
# 3977   129.807301       99.763264
# 3988   129.230186      100.208785
# 3498   146.713401      102.580950
# 3719   141.034446      104.832546
# 3255   150.014817      105.322930

# %%
best_grandland = df[df[Column.NAME].str.contains('Grandland')].iloc[0][VIEW_COLUMNS]
grandland_score = best_grandland[Column.TOTAL_SCORE]
grandland_euro_per_score = best_grandland[Column.EURO_PER_SCORE]
best_grandland
# Out:
# name                Opel Grandland 1.6 DI Turbo Hybrid Elegance Au...
# Grundpreis|fixed                                              45700.0
# Total Score                                                189.534549
# Euro per score                                              241.11699
# Name: 67, dtype: object

# %% [markdown]
# # Better than Grandland by points

# %%
d = df[df[Column.TOTAL_SCORE] >= grandland_score]
d[VIEW_COLUMNS].reset_index(drop=True).head(VIEW_LIMIT)
# Out:
#                                                 name  Grundpreis|fixed  \
# 0  Hyundai IONIQ 6 (53 kWh) TECHNIQ-Paket 2WD (ab...           52100.0
# 1  Hyundai IONIQ 5 (58 kWh) DYNAMIQ-Paket 2WD (ab...           50800.0
# 2  VinFast VF 8 Eco (82 kWh) AWD (zzgl. Battermie...           45700.0
# 3  VinFast VF 8 Eco (87,7 kWh) AWD (zzgl. Batterm...           46000.0
# 4  Hyundai IONIQ 5 (77,4 kWh) DYNAMIQ-Paket 2WD (...           54800.0
# 5  Hyundai IONIQ 5 (58 kWh) TECHNIQ-Paket 2WD (ab...           53200.0
# 6          KIA EV6 (77,4 kWh) GT Line 4WD (ab 10/21)           60890.0
# 7  Hyundai IONIQ 6 (53 kWh) DYNAMIC-Paket 2WD (ab...           49000.0
# 8  Hyundai IONIQ 6 (77,4 kWh) UNIQ-Paket 2WD (ab ...           60200.0
# 9                 Subaru Solterra Comfort (ab 10/22)           57490.0
#
#    Total Score  Euro per score
# 0   198.483868      262.489846
# 1   198.475303      255.951241
# 2   198.130378      230.656199
# 3   198.104653      232.200503
# 4   197.339350      277.694236
# 5   197.212145      269.760263
# 6   197.197424      308.776853
# 7   197.143931      248.549371
# 8   196.964940      305.638150
# 9   196.641411      292.359579

# %% [markdown]
# # Better than Grandland by points and euro per point

# %%
d = df[(df[Column.TOTAL_SCORE] >= grandland_score) & (df[Column.EURO_PER_SCORE] <= grandland_euro_per_score)]
d[VIEW_COLUMNS].reset_index(drop=True).head(VIEW_LIMIT)
# Out:
#                                                 name  Grundpreis|fixed  \
# 0  VinFast VF 8 Eco (82 kWh) AWD (zzgl. Battermie...           45700.0
# 1  VinFast VF 8 Eco (87,7 kWh) AWD (zzgl. Batterm...           46000.0
# 2     KIA Niro 1.6 GDI Hybrid Spirit DCT6 (ab 06/22)           37290.0
# 3              Nissan Leaf (40 kWh) Tekna (ab 05/19)           38200.0
# 4         Nissan Leaf (40 kWh) N-CONNECTA (ab 05/19)           35900.0
# 5    Honda Jazz 1.5 i-MMD Executive e-CVT (ab 07/20)           27000.0
# 6  KIA Niro 1.6 GDI PlugIn-Hybrid Spirit DCT6 (ab...           43490.0
# 7  Honda Jazz 1.5 i-MMD Executive Style e-CVT (ab...           28600.0
# 8        KIA XCeed 1.5 T-GDI GT-Line DCT7 (ab 07/22)           35190.0
# 9  Honda e Advance-Paket (16 Zoll Bereifung) (ab ...           39900.0
#
#    Total Score  Euro per score
# 0   198.130378      230.656199
# 1   198.104653      232.200503
# 2   194.062806      192.154287
# 3   193.921007      196.987426
# 4   193.523480      185.507206
# 5   193.367645      139.630391
# 6   193.250210      225.045034
# 7   192.477388      148.588883
# 8   192.452402      182.850407
# 9   191.972608      207.842153

# %% [markdown]
# # Better than Grandland by points and euro per point and cheaper

# %%
d = df[
    (df[Column.TOTAL_SCORE] >= grandland_score) & 
    (df[Column.EURO_PER_SCORE] <= grandland_euro_per_score) & 
    (df[FIXED_PRICE_COLUMN] <= best_grandland[FIXED_PRICE_COLUMN])
]
d[VIEW_COLUMNS].reset_index(drop=True).head(VIEW_LIMIT)
# Out:
#                                                 name  Grundpreis|fixed  \
# 0  VinFast VF 8 Eco (82 kWh) AWD (zzgl. Battermie...           45700.0
# 1     KIA Niro 1.6 GDI Hybrid Spirit DCT6 (ab 06/22)           37290.0
# 2              Nissan Leaf (40 kWh) Tekna (ab 05/19)           38200.0
# 3         Nissan Leaf (40 kWh) N-CONNECTA (ab 05/19)           35900.0
# 4    Honda Jazz 1.5 i-MMD Executive e-CVT (ab 07/20)           27000.0
# 5  KIA Niro 1.6 GDI PlugIn-Hybrid Spirit DCT6 (ab...           43490.0
# 6  Honda Jazz 1.5 i-MMD Executive Style e-CVT (ab...           28600.0
# 7        KIA XCeed 1.5 T-GDI GT-Line DCT7 (ab 07/22)           35190.0
# 8  Honda e Advance-Paket (16 Zoll Bereifung) (ab ...           39900.0
# 9        Mazda MX-30 e-SKYACTIV EV Makoto (ab 04/22)           38490.0
#
#    Total Score  Euro per score
# 0   198.130378      230.656199
# 1   194.062806      192.154287
# 2   193.921007      196.987426
# 3   193.523480      185.507206
# 4   193.367645      139.630391
# 5   193.250210      225.045034
# 6   192.477388      148.588883
# 7   192.452402      182.850407
# 8   191.972608      207.842153
# 9   191.879366      200.594784
