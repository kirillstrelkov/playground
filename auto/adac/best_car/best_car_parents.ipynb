# %%
from find_best_car import (
    Column, 
    get_scored_df,
    _get_fixed_column_name,
)

df = get_scored_df(feature_file_name="feature_parents.csv")
# Out:
# /home/kirill/workspace/github/playground/auto/adac/best_car/find_best_car.py:353: DtypeWarning: Columns (238,239,240) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_df[_get_fixed_column_name(Column.PRICE)] / new_df[Column.TOTAL_SCORE]
# 2023-03-20 09:43:44.932 | WARNING  | find_best_car:get_scored_df:415 - Duplicates:
#         id                                                                                               name
# 0   325888                         Dacia Sandero Stepway TCe 100 ECO-G Expression (Autogasbetrieb) (ab 07/22)
# 1   325890                          Dacia Sandero Stepway TCe 100 ECO-G Expression (Benzinbetrieb) (ab 07/22)
# 2   322610                                                 Dacia Jogger TCe 110 Extreme (7-Sitzer) (ab 03/22)
# 3   325569                                            Renault Arkana Mild Hybrid 140 Equilibre EDC (ab 06/22)
# 4   317862                                                               Audi A3 Sportback 35 TFSI (ab 11/20)
# 5   321830                                                           Ford Fiesta ST 1.5 EcoBoost X (ab 03/22)
# 6   318876                                                   Hyundai Kona 1.6 GDI Hybrid Trend DCT (ab 01/21)
# 7   324865                                                       Renault Mégane TCe 140 GPF Techno (ab 04/22)
# 8   319820                           Ford Puma 1.0 EcoBoost Hybrid Titanium X PowerShift Automatik (ab 03/21)
# 9   319771                                                       Audi A3 Sportback 35 TDI advanced (ab 01/21)
# 10  320481                                                            Lynk & Co 01 1.5TD PHEV DCTH (ab 04/21)
# 11  324780                                     VinFast VF 8 Eco (87,7 kWh) AWD (zzgl. Battermiete) (ab 04/23)
# 12  327298                               Abarth 500e Cabrio (42 kWh) Scorpionissima Launch Edition (ab 04/23)
# 13  324897                                           BMW 116d Edition Colorvision Steptronic (DKG) (ab 07/22)
# 14  321101                               DS Automobiles DS 4 E-Tense 225 Cross Trocadero Automatik (ab 10/21)
# 15  313479                                                      Audi A5 Sportback 40 TFSI S tronic (ab 07/20)
# 16  313488                                                          Audi A5 Coupé 40 TFSI S tronic (ab 07/20)
# 17  325251                                                  BMW 220d Coupé M Sportpaket Steptronic (ab 07/22)
# 18  326765          Alfa Romeo Tonale 1.3 T Multiair Plug-in Hybrid Edizione Speciale Q4 Automatik (ab 06/23)
# 19  312689                                                               BMW 420i Coupé Steptronic (ab 10/20)
# 20  326672  MINI Clubman John Cooper Works Untold Edition inkl. Paket Premium Plus ALL4 Steptronic (ab 07/22)
# 21  316415                                                   Jaguar XE P250 R-Dynamic SE Automatik (ab 01/21)
# 22  312694                                                        BMW 420d Coupé xDrive Steptronic (ab 10/20)
# /home/kirill/workspace/github/playground/auto/adac/best_car/find_best_car.py:523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for name in possible_names:
# /home/kirill/workspace/github/playground/auto/adac/best_car/find_best_car.py:523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for name in possible_names:

# %% [markdown]
# # Best cars by score

# %%
FIXED_PRICE_COLUMN = _get_fixed_column_name(Column.PRICE)
VIEW_COLUMNS = [Column.NAME, FIXED_PRICE_COLUMN, Column.TOTAL_SCORE, Column.EURO_PER_SCORE]
VIEW_LIMIT = 20

df[VIEW_COLUMNS].head(VIEW_LIMIT)
# Out:
#                                                  name  Grundpreis|fixed  \
# 0   VinFast VF 8 Eco (87,7 kWh) AWD (zzgl. Batterm...           46000.0
# 1   VinFast VF 8 Eco (82 kWh) AWD (zzgl. Battermie...           45700.0
# 2   Hyundai IONIQ 6 (53 kWh) TECHNIQ-Paket 2WD (ab...           52100.0
# 3   Hyundai IONIQ 6 (77,4 kWh) TECHNIQ-Paket 2WD (...           57100.0
# 4   Hyundai IONIQ 5 (58 kWh) DYNAMIQ-Paket 2WD (ab...           50800.0
# 5   Hyundai IONIQ 6 (77,4 kWh) UNIQ-Paket 2WD (ab ...           60200.0
# 6          KIA e-Soul (64 kWh) Inspiration (ab 11/22)           46950.0
# 7               KIA EV6 (77,4 kWh) GT Line (ab 10/21)           56990.0
# 8           KIA EV6 (77,4 kWh) GT Line 4WD (ab 10/21)           60890.0
# 9   Hyundai IONIQ 5 (77,4 kWh) DYNAMIQ-Paket 2WD (...           54800.0
# 10  Hyundai IONIQ 6 (77,4 kWh) TECHNIQ-Paket 4WD (...           61100.0
# 11  Hyundai IONIQ 5 (58 kWh) TECHNIQ-Paket 2WD (ab...           53200.0
# 12  Hyundai IONIQ 6 (77,4 kWh) UNIQ-Paket 4WD (ab ...           64200.0
# 13  VinFast VF 8 Plus (87,7 kWh) AWD (zzgl. Batter...           52600.0
# 14  Hyundai IONIQ 6 (53 kWh) DYNAMIC-Paket 2WD (ab...           49000.0
# 15  Hyundai IONIQ 5 (77,4 kWh) TECHNIQ-Paket 2WD (...           57200.0
# 16  VinFast VF 8 Plus (82 kWh) AWD (zzgl. Battermi...           52300.0
# 17    MG MG4 Electric Maximum Range Luxury (ab 09/22)           37990.0
# 18  Hyundai IONIQ 5 (77,4 kWh) UNIQ-Paket 2WD (ab ...           60900.0
# 19  Hyundai IONIQ 6 (77,4 kWh) DYNAMIC-Paket 2WD (...           54000.0
#
#     Total Score  Euro per score
# 0    239.879287      191.763118
# 1    239.481600      190.828857
# 2    238.367674      218.569906
# 3    236.597138      241.338507
# 4    236.316105      214.966305
# 5    235.906323      255.186038
# 6    235.753798      199.148435
# 7    235.558821      241.935326
# 8    235.218980      258.865164
# 9    235.132326      233.060256
# 10   234.707721      260.323775
# 11   234.210842      227.145761
# 12   234.016907      274.339153
# 13   233.307746      225.453294
# 14   233.115456      210.196273
# 15   233.027063      245.465052
# 16   232.943672      224.517796
# 17   232.509934      163.390868
# 18   231.809932      262.715231
# 19   231.344920      233.417704

# %% [markdown]
# # Best cars by euro per score

# %%
df[VIEW_COLUMNS].sort_values([Column.EURO_PER_SCORE, Column.TOTAL_SCORE]).head(VIEW_LIMIT)
# Out:
#                                                    name  Grundpreis|fixed  \
# 3898          Dacia Sandero SCe 65 Essential (ab 01/21)           10750.0
# 3063         Dacia Sandero TCe 90 Expression (ab 06/22)           13750.0
# 3870          Dacia Sandero TCe 90 Essential (ab 01/21)           12350.0
# 3133  Dacia Sandero TCe 100 ECO-G Expression (Benzin...           14350.0
# 3175  Dacia Sandero TCe 100 ECO-G Expression (Autoga...           14350.0
# 3885  Dacia Sandero TCe 100 ECO-G Essential (Benzinb...           12950.0
# 3900  Dacia Sandero TCe 100 ECO-G Essential (Autogas...           12950.0
# 5867                            Opel Rocks-e (ab 03/22)            7990.0
# 3075     Dacia Sandero TCe 90 Expression CVT (ab 06/22)           15050.0
# 3142  Dacia Sandero Stepway TCe 90 Expression (ab 06...           15400.0
# 2950            Hyundai i10 1.0 Connect & Go (ab 06/22)           15800.0
# 3721                  Hyundai i10 1.0 Select (ab 09/20)           14785.0
# 3873  Dacia Sandero Stepway TCe 90 Essential (ab 01/21)           14300.0
# 3119  Dacia Sandero Stepway TCe 100 ECO-G Expression...           16000.0
# 3152  Dacia Sandero Stepway TCe 100 ECO-G Expression...           16000.0
# 5887                      Opel Rocks-e Tekno (ab 12/21)            8790.0
# 5888                       Opel Rocks-e Klub (ab 03/22)            8790.0
# 2996  Dacia Sandero Stepway TCe 110 Expression (ab 0...           16400.0
# 3115                   Hyundai i10 1.0 Trend (ab 09/20)           16490.0
# 3889  Dacia Sandero Stepway TCe 100 ECO-G Essential ...           14900.0
#
#       Total Score  Euro per score
# 3898   156.784605       68.565405
# 3063   177.413337       77.502629
# 3870   158.104808       78.112742
# 3133   176.553523       81.278469
# 3175   176.043144       81.514109
# 3885   157.244993       82.355563
# 3900   156.734615       82.623739
# 5867    96.309811       82.961434
# 3075   177.256947       84.904994
# 3142   176.430758       87.286368
# 2950   178.966954       88.284455
# 3721   165.199867       89.497651
# 3873   157.972995       90.521801
# 3119   176.740578       90.528164
# 3152   176.341620       90.732976
# 5887    95.608056       91.937859
# 5888    95.608056       91.937859
# 2996   178.372213       91.942572
# 3115   176.753708       93.293658
# 3889   157.168890       94.802476

# %%
best_grandland = df[df[Column.NAME].str.contains('Grandland')].iloc[0][VIEW_COLUMNS]
grandland_score = best_grandland[Column.TOTAL_SCORE]
grandland_euro_per_score = best_grandland[Column.EURO_PER_SCORE]
best_grandland
# Out:
# name                Opel Grandland 1.6 DI Turbo Hybrid Elegance Au...
# Grundpreis|fixed                                              45700.0
# Total Score                                                222.163191
# Euro per score                                             205.704644
# Name: 81, dtype: object

# %% [markdown]
# # Better than Grandland by points

# %%
d = df[df[Column.TOTAL_SCORE] >= grandland_score]
d[VIEW_COLUMNS].reset_index(drop=True).head(VIEW_LIMIT)
# Out:
#                                                  name  Grundpreis|fixed  \
# 0   VinFast VF 8 Eco (87,7 kWh) AWD (zzgl. Batterm...           46000.0
# 1   VinFast VF 8 Eco (82 kWh) AWD (zzgl. Battermie...           45700.0
# 2   Hyundai IONIQ 6 (53 kWh) TECHNIQ-Paket 2WD (ab...           52100.0
# 3   Hyundai IONIQ 6 (77,4 kWh) TECHNIQ-Paket 2WD (...           57100.0
# 4   Hyundai IONIQ 5 (58 kWh) DYNAMIQ-Paket 2WD (ab...           50800.0
# 5   Hyundai IONIQ 6 (77,4 kWh) UNIQ-Paket 2WD (ab ...           60200.0
# 6          KIA e-Soul (64 kWh) Inspiration (ab 11/22)           46950.0
# 7               KIA EV6 (77,4 kWh) GT Line (ab 10/21)           56990.0
# 8           KIA EV6 (77,4 kWh) GT Line 4WD (ab 10/21)           60890.0
# 9   Hyundai IONIQ 5 (77,4 kWh) DYNAMIQ-Paket 2WD (...           54800.0
# 10  Hyundai IONIQ 6 (77,4 kWh) TECHNIQ-Paket 4WD (...           61100.0
# 11  Hyundai IONIQ 5 (58 kWh) TECHNIQ-Paket 2WD (ab...           53200.0
# 12  Hyundai IONIQ 6 (77,4 kWh) UNIQ-Paket 4WD (ab ...           64200.0
# 13  VinFast VF 8 Plus (87,7 kWh) AWD (zzgl. Batter...           52600.0
# 14  Hyundai IONIQ 6 (53 kWh) DYNAMIC-Paket 2WD (ab...           49000.0
# 15  Hyundai IONIQ 5 (77,4 kWh) TECHNIQ-Paket 2WD (...           57200.0
# 16  VinFast VF 8 Plus (82 kWh) AWD (zzgl. Battermi...           52300.0
# 17    MG MG4 Electric Maximum Range Luxury (ab 09/22)           37990.0
# 18  Hyundai IONIQ 5 (77,4 kWh) UNIQ-Paket 2WD (ab ...           60900.0
# 19  Hyundai IONIQ 6 (77,4 kWh) DYNAMIC-Paket 2WD (...           54000.0
#
#     Total Score  Euro per score
# 0    239.879287      191.763118
# 1    239.481600      190.828857
# 2    238.367674      218.569906
# 3    236.597138      241.338507
# 4    236.316105      214.966305
# 5    235.906323      255.186038
# 6    235.753798      199.148435
# 7    235.558821      241.935326
# 8    235.218980      258.865164
# 9    235.132326      233.060256
# 10   234.707721      260.323775
# 11   234.210842      227.145761
# 12   234.016907      274.339153
# 13   233.307746      225.453294
# 14   233.115456      210.196273
# 15   233.027063      245.465052
# 16   232.943672      224.517796
# 17   232.509934      163.390868
# 18   231.809932      262.715231
# 19   231.344920      233.417704

# %% [markdown]
# # Better than Grandland by points and euro per point

# %%
d = df[(df[Column.TOTAL_SCORE] >= grandland_score) & (df[Column.EURO_PER_SCORE] <= grandland_euro_per_score)]
d[VIEW_COLUMNS].reset_index(drop=True).head(VIEW_LIMIT)
# Out:
#                                                  name  Grundpreis|fixed  \
# 0   VinFast VF 8 Eco (87,7 kWh) AWD (zzgl. Batterm...           46000.0
# 1   VinFast VF 8 Eco (82 kWh) AWD (zzgl. Battermie...           45700.0
# 2          KIA e-Soul (64 kWh) Inspiration (ab 11/22)           46950.0
# 3     MG MG4 Electric Maximum Range Luxury (ab 09/22)           37990.0
# 4                         KIA EV6 (58 kWh) (ab 10/21)           46990.0
# 5     Mazda MX-30 e-SKYACTIV EV Prime-Line (ab 04/22)           35990.0
# 6               Nissan Leaf (40 kWh) Tekna (ab 05/19)           38200.0
# 7     Mazda MX-30 e-SKYACTIV EV Ad´vantage (ab 04/22)           36490.0
# 8         Mazda MX-30 e-SKYACTIV EV Makoto (ab 04/22)           38490.0
# 9     Honda Jazz 1.5 i-MMD Executive e-CVT (ab 07/20)           27000.0
# 10         Nissan Leaf (40 kWh) N-CONNECTA (ab 05/19)           35900.0
# 11  Mazda MX-30 e-SKYACTIV EV Exclusive-Line (ab 0...           36990.0
# 12     KIA Niro 1.6 GDI Hybrid Spirit DCT6 (ab 06/22)           37290.0
# 13  Honda Jazz 1.5 i-MMD Executive Style e-CVT (ab...           28600.0
# 14  KIA Niro 1.6 GDI PlugIn-Hybrid Spirit DCT6 (ab...           43490.0
# 15           Nissan Leaf (62 kWh) e+ Tekna (ab 05/19)           43400.0
# 16      Nissan Leaf (62 kWh) e+ N-CONNECTA (ab 05/19)           41100.0
# 17  Honda e Advance-Paket (16 Zoll Bereifung) (ab ...           39900.0
# 18     KIA Niro 1.6 GDI Hybrid Vision DCT6 (ab 06/22)           33990.0
# 19  Honda e Advance-Paket (17 Zoll Bereifung) (ab ...           40500.0
#
#     Total Score  Euro per score
# 0    239.879287      191.763118
# 1    239.481600      190.828857
# 2    235.753798      199.148435
# 3    232.509934      163.390868
# 4    231.257651      203.193277
# 5    230.795597      155.938850
# 6    230.567459      165.678193
# 7    230.357000      158.406300
# 8    230.102614      167.273197
# 9    230.071352      117.354898
# 10   230.051413      156.052073
# 11   229.918404      160.883163
# 12   229.760026      162.299773
# 13   228.612133      125.102722
# 14   227.960214      190.778905
# 15   227.795546      190.521723
# 16   227.279500      180.834611
# 17   227.007300      175.765272
# 18   226.550823      150.032560
# 19   226.166621      179.071517

# %% [markdown]
# # Better than Grandland by points and euro per point and cheaper

# %%
d = df[
    (df[Column.TOTAL_SCORE] >= grandland_score) & 
    (df[Column.EURO_PER_SCORE] <= grandland_euro_per_score) & 
    (df[FIXED_PRICE_COLUMN] <= best_grandland[FIXED_PRICE_COLUMN])
]
d[VIEW_COLUMNS].reset_index(drop=True).head(VIEW_LIMIT)
# Out:
#                                                  name  Grundpreis|fixed  \
# 0   VinFast VF 8 Eco (82 kWh) AWD (zzgl. Battermie...           45700.0
# 1     MG MG4 Electric Maximum Range Luxury (ab 09/22)           37990.0
# 2     Mazda MX-30 e-SKYACTIV EV Prime-Line (ab 04/22)           35990.0
# 3               Nissan Leaf (40 kWh) Tekna (ab 05/19)           38200.0
# 4     Mazda MX-30 e-SKYACTIV EV Ad´vantage (ab 04/22)           36490.0
# 5         Mazda MX-30 e-SKYACTIV EV Makoto (ab 04/22)           38490.0
# 6     Honda Jazz 1.5 i-MMD Executive e-CVT (ab 07/20)           27000.0
# 7          Nissan Leaf (40 kWh) N-CONNECTA (ab 05/19)           35900.0
# 8   Mazda MX-30 e-SKYACTIV EV Exclusive-Line (ab 0...           36990.0
# 9      KIA Niro 1.6 GDI Hybrid Spirit DCT6 (ab 06/22)           37290.0
# 10  Honda Jazz 1.5 i-MMD Executive Style e-CVT (ab...           28600.0
# 11  KIA Niro 1.6 GDI PlugIn-Hybrid Spirit DCT6 (ab...           43490.0
# 12           Nissan Leaf (62 kWh) e+ Tekna (ab 05/19)           43400.0
# 13      Nissan Leaf (62 kWh) e+ N-CONNECTA (ab 05/19)           41100.0
# 14  Honda e Advance-Paket (16 Zoll Bereifung) (ab ...           39900.0
# 15     KIA Niro 1.6 GDI Hybrid Vision DCT6 (ab 06/22)           33990.0
# 16  Honda e Advance-Paket (17 Zoll Bereifung) (ab ...           40500.0
# 17  Toyota Yaris Cross 1.5 Hybrid Elegant CVT (ab ...           32690.0
# 18  Honda Civic 2.0 i-MMD Hybrid Sport e-CVT (ab 1...           34200.0
# 19  Honda Civic 2.0 i-MMD Hybrid Elegance e-CVT (a...           32900.0
#
#     Total Score  Euro per score
# 0    239.481600      190.828857
# 1    232.509934      163.390868
# 2    230.795597      155.938850
# 3    230.567459      165.678193
# 4    230.357000      158.406300
# 5    230.102614      167.273197
# 6    230.071352      117.354898
# 7    230.051413      156.052073
# 8    229.918404      160.883163
# 9    229.760026      162.299773
# 10   228.612133      125.102722
# 11   227.960214      190.778905
# 12   227.795546      190.521723
# 13   227.279500      180.834611
# 14   227.007300      175.765272
# 15   226.550823      150.032560
# 16   226.166621      179.071517
# 17   226.078575      144.595745
# 18   225.892566      151.399405
# 19   225.604037      145.830724
