# %% [markdown]
# # Analysis of stock prices in different time periods
#
#
# **NOTE:** `base date point` means that base value will be set to the first date in dataset.
#
# Example: if we want to get daily prices within a week then `base date point` means that the base value will be set **only** for data point with first date

# %%
import sys

sys.path.append('..')

from analysis_base_first_date import Column
from common import plot, YahooRange

from loguru import logger
import numpy as np
import pandas as pd
from seaborn import lineplot, barplot, scatterplot, boxplot
from matplotlib import pyplot


FILENAME = "dax/dax_mdax_sdax.csv"
LIMIT = None

logger.remove()
logger.add(sys.stdout, level="INFO")

pass

# %% [markdown]
# ## Monthly stock price fluctuations within a year

# %%
from analysis_base_first_date import get_best_month

df = get_best_month(FILENAME, YahooRange.YEARS_20, limit=LIMIT)
df
# Out:
#        year  month   Symbol  Percent (mean)
# 0      2018      1  BFSA.DE           100.0
# 1      2018      2  BFSA.DE       99.130439
# 2      2018      3  BFSA.DE      104.347826
# 3      2018      4  BFSA.DE      104.347826
# 4      2018      5  BFSA.DE      103.975151
# ...     ...    ...      ...             ...
# 29353  2017      8      LIN      470.385633
# 29354  2017      9      LIN      470.493252
# 29355  2017     10      LIN      500.771287
# 29356  2017     11      LIN      533.130047
# 29357  2017     12      LIN      551.497743
#
# [29358 rows x 4 columns]

# %%
plot(x=Column.MONTH, y=Column.PERCENT, data=df)
# Out:
#        Percent (mean)
# month
# 1          406.242157
# 2           372.53884
# 3           375.20034
# 4          373.870261
# 5           393.60106

# %% [markdown]
# ## Weekly stock price fluctuations within a year

# %%
from analysis_base_first_date import get_best_week

df = get_best_week(FILENAME, YahooRange.YEARS_20, limit=LIMIT)

df
# Out:
#         year  week   Symbol  Percent (mean)
# 0       2017    52  BFSA.DE           100.0
# 1       2018     1  BFSA.DE      103.205128
# 2       2018     2  BFSA.DE      104.487179
# 3       2018     3  BFSA.DE      102.435899
# 4       2018     4  BFSA.DE      101.282051
# ...      ...   ...      ...             ...
# 127491  2006    44      LIN      216.694063
# 127492  2006    45      LIN      223.452048
# 127493  2006    46      LIN        225.6073
# 127494  2006    47      LIN      230.283108
# 127495  2006    48      LIN       231.19635
#
# [127496 rows x 4 columns]

# %%
plot(x=Column.WEEK, y=Column.PERCENT, data=df)
# Out:
#       Percent (mean)
# week
# 1         364.699761
# 2         367.176318
# 3         367.846184
# 4         374.149576
# 5         374.424538

# %% [markdown]
# ## Daily stock price fluctuations within a month

# %%
from analysis_base_first_date import get_best_month_day

df = get_best_month_day(FILENAME, YahooRange.YEARS_20, limit=LIMIT)

df
# Out:
#         year  month  day  Symbol  Percent (mean)
# 0       2018     10   12  KBX.DE           100.0
# 1       2018     10   15  KBX.DE      102.372037
# 2       2018     10   16  KBX.DE      104.119854
# 3       2018     10   17  KBX.DE        105.1186
# 4       2018     10   18  KBX.DE      106.117355
# ...      ...    ...  ...     ...             ...
# 621733  2007     10   24  MBG.DE      152.016551
# 621734  2007     10   25  MBG.DE      155.118929
# 621735  2007     10   26  MBG.DE      162.357813
# 621736  2007     10   29  MBG.DE      159.875916
# 621737  2007     10   30  MBG.DE      159.255434
#
# [621738 rows x 5 columns]

# %%
plot(x=Column.DAY, y=Column.PERCENT, data=df)
# Out:
#      Percent (mean)
# day
# 1        389.050859
# 2        392.745644
# 3        391.896358
# 4        391.189915
# 5        391.855421

# %% [markdown]
# ## Daily stock price fluctuations within a week

# %%
from analysis_base_first_date import get_best_weekday


df = get_best_weekday(FILENAME, YahooRange.YEARS_20, limit=LIMIT)

df
# Out:
#         year  week  weekday  Percent (mean)
# 0       2018    41        4           100.0
# 1       2018    42        0      102.372037
# 2       2018    42        1      104.119854
# 3       2018    42        2        105.1186
# 4       2018    42        3      106.117355
# ...      ...   ...      ...             ...
# 621733  2007    43        2      152.016551
# 621734  2007    43        3      155.118929
# 621735  2007    43        4      162.357813
# 621736  2007    44        0      159.875916
# 621737  2007    44        1      159.255434
#
# [621738 rows x 4 columns]

# %%
plot(x=Column.WEEKDAY, y=Column.PERCENT, data=df)
# Out:
#          Percent (mean)
# weekday
# 0            392.994398
# 1             394.41991
# 2            394.835565
# 3            394.767737
# 4            392.749314

# %% [markdown]
# ## Hourly stock price fluctuations within a day

# %%
from analysis_base_first_date import get_best_hour

df = get_best_hour(FILENAME, YahooRange.YEARS_2, limit=LIMIT)

df
# Out:
#         year  week  day  hour  Symbol  Percent (mean)
# 0       2020    48   23     8  G24.DE           100.0
# 1       2020    48   23     9  G24.DE        99.84436
# 2       2020    48   23    10  G24.DE       98.988324
# 3       2020    48   23    11  G24.DE        99.22179
# 4       2020    48   23    12  G24.DE        99.37743
# ...      ...   ...  ...   ...     ...             ...
# 711927  2022    46   17    17     LIN      130.218549
# 711928  2022    46   17    18     LIN      130.086637
# 711929  2022    46   17    19     LIN      129.671192
# 711930  2022    46   17    20     LIN      129.517625
# 711931  2022    46   18    21     LIN      131.880294
#
# [711932 rows x 6 columns]

# %%
plot(x=Column.HOUR, y=Column.PERCENT, data=df)
# Out:
#       Percent (mean)
# hour
# 6         151.156206
# 7         107.522755
# 8         108.594778
# 9         108.560254
# 10         108.63321

# %% [markdown]
# ## Hourly and quarterly stock price fluctuations within an day

# %%
from analysis_base_first_date import get_best_time

df = get_best_time(FILENAME, YahooRange.DAYS_58, limit=LIMIT)

df
# Out:
#         year  week  day  hour  minute  time  Symbol  Percent (mean)
# 0       2022    38   21     7       0   7.0  ADJ.DE           100.0
# 1       2022    38   21     7      30   7.5  ADJ.DE        99.07251
# 2       2022    38   21     8       0   8.0  ADJ.DE        99.15683
# 3       2022    38   21     8      30   8.5  ADJ.DE       98.397982
# 4       2022    38   21     9       0   9.0  ADJ.DE       99.241151
# ...      ...   ...  ...   ...     ...   ...     ...             ...
# 108036  2022    46   17    19       0  19.0     LIN      117.058068
# 108037  2022    46   17    19      30  19.5     LIN      116.818607
# 108038  2022    46   17    20       0  20.0     LIN      116.829249
# 108039  2022    46   17    20      30  20.5     LIN      116.680261
# 108040  2022    46   18    21       0  21.0     LIN       118.80875
#
# [108041 rows x 8 columns]

# %%
# NOTE: filter extreme points, plot df first and if charts are bad try with fdf
fdf = df[df[Column.TIME].isin(np.arange(9, 15.5, 0.25))].copy()

plot(x=Column.TIME, y=Column.PERCENT, data=fdf)
# Out:
#       Percent (mean)
# time
# 9.0       100.742921
# 9.5       100.760177
# 10.0      100.716343
# 10.5      100.768785
# 11.0      100.768782

# %% [markdown]
# ## Quarterly stock price fluctuations within an hour

# %%
from analysis_base_first_date import get_best_quarter

df = get_best_quarter(FILENAME, YahooRange.DAYS_58, limit=LIMIT)

df
# Out:
#         year  week  day  hour  minute  quarter  Symbol  Percent (mean)
# 0       2022    38   21     7       0        0  ADJ.DE           100.0
# 1       2022    38   21     7      15       15  ADJ.DE      100.337274
# 2       2022    38   21     7      45       45  ADJ.DE        99.07251
# 3       2022    38   21     8       0        0  ADJ.DE        99.15683
# 4       2022    38   21     8      15       15  ADJ.DE       98.735246
# ...      ...   ...  ...   ...     ...      ...     ...             ...
# 205435  2022    46   17    20       0        0     LIN      116.829249
# 205436  2022    46   17    20      15       15     LIN      116.648335
# 205437  2022    46   17    20      30       30     LIN      116.680261
# 205438  2022    46   17    20      45       45     LIN      116.864726
# 205439  2022    46   18    21       0        0     LIN       118.80875
#
# [205440 rows x 8 columns]

# %%
plot(x=Column.QUARTER, y=Column.PERCENT, data=df)
# Out:
#          Percent (mean)
# quarter
# 0            100.811571
# 15           100.884485
# 30            100.90821
# 45           100.855873
