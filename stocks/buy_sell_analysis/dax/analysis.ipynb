# %% [markdown]
# # Analysis of stock prices in different time periods
#
# **NOTE:** `base date point` will be set separatly for each period.
#
# Example: if we want to get daily prices within a week then each Monday will be set as `base date point`

# %%
import sys

sys.path.append('..')

from analysis import Column
from common import plot, YahooRange

from loguru import logger
import numpy as np
import pandas as pd
from seaborn import lineplot, barplot, scatterplot, boxplot
from matplotlib import pyplot


FILENAME = "dax/dax_mdax_sdax.csv"
LIMIT = None

logger.remove()
logger.add(sys.stdout, level="INFO")

pass

# %% [markdown]
# ## Monthly stock price fluctuations within a year

# %%
from analysis import get_best_month

df = get_best_month(FILENAME, YahooRange.YEARS_20, limit=LIMIT)
df
# Out:
#        year  month   Symbol  Percent (mean)
# 0      2018      1  BFSA.DE           100.0
# 1      2018      2  BFSA.DE       99.130439
# 2      2018      3  BFSA.DE      104.347826
# 3      2018      4  BFSA.DE      104.347826
# 4      2018      5  BFSA.DE      103.975151
# ...     ...    ...      ...             ...
# 28543  2017      8      LIN      111.146896
# 28544  2017      9      LIN      111.172326
# 28545  2017     10      LIN      118.326689
# 28546  2017     11      LIN      125.972704
# 28547  2017     12      LIN      130.312786
#
# [28548 rows x 4 columns]

# %%
plot(x=Column.MONTH, y=Column.PERCENT, data=df)
# Out:
#        Percent (mean)
# month
# 1               100.0
# 2          102.322883
# 3            103.3264
# 4          103.972038
# 5           107.82401

# %% [markdown]
# ## Weekly stock price fluctuations within a year

# %%
from analysis import get_best_week

df = get_best_week(FILENAME, YahooRange.YEARS_20, limit=LIMIT)

df
# Out:
#         year  week   Symbol  Percent (mean)
# 0       2018     1  BFSA.DE           100.0
# 1       2018     2  BFSA.DE      101.242236
# 2       2018     3  BFSA.DE        99.25466
# 3       2018     4  BFSA.DE       98.136646
# 4       2018     5  BFSA.DE      101.366458
# ...      ...   ...      ...             ...
# 125839  2005    48      LIN      118.376554
# 125840  2005    49      LIN      118.827514
# 125841  2005    50      LIN      119.549047
# 125842  2005    51      LIN      117.542284
# 125843  2005    52      LIN      121.803838
#
# [125844 rows x 4 columns]

# %%
plot(x=Column.WEEK, y=Column.PERCENT, data=df)
# Out:
#       Percent (mean)
# week
# 1         100.370793
# 2         110.017268
# 3         109.336221
# 4         109.116395
# 5         109.199337

# %% [markdown]
# ## Daily stock price fluctuations within a month

# %%
from analysis import Column,get_best_month_day

df = get_best_month_day(FILENAME, YahooRange.YEARS_20, limit=LIMIT)

df
# Out:
#         year  month  day  Symbol  Percent (mean)
# 0       2018     11    1  KBX.DE           100.0
# 1       2018     11    2  KBX.DE      101.772435
# 2       2018     11    5  KBX.DE      103.482892
# 3       2018     11    6  KBX.DE      104.090237
# 4       2018     11    7  KBX.DE      103.743179
# ...      ...    ...  ...     ...             ...
# 614519  2006      9   25  MBG.DE       94.733005
# 614520  2006      9   26  MBG.DE       96.116499
# 614521  2006      9   27  MBG.DE       96.310679
# 614522  2006      9   28  MBG.DE       96.844662
# 614523  2006      9   29  MBG.DE       95.873785
#
# [614524 rows x 5 columns]

# %%
plot(x=Column.DAY, y=Column.PERCENT, data=df)
# Out:
#      Percent (mean)
# day
# 1             100.0
# 2        100.108412
# 3        100.307071
# 4         100.32014
# 5        100.243993

# %% [markdown]
# ## Daily stock price fluctuations within a week

# %%
from analysis import get_best_weekday


df = get_best_weekday(FILENAME, YahooRange.YEARS_20, limit=LIMIT)

df
# Out:
#         year  week  weekday  Symbol  Percent (mean)
# 0       2018    42        0  KBX.DE           100.0
# 1       2018    42        1  KBX.DE      101.707319
# 2       2018    42        2  KBX.DE      102.682923
# 3       2018    42        3  KBX.DE      103.658537
# 4       2018    42        4  KBX.DE       101.58537
# ...      ...   ...      ...     ...             ...
# 619074  2006    40        0  MBG.DE           100.0
# 619075  2006    40        1  MBG.DE       99.017634
# 619076  2006    40        2  MBG.DE       97.481108
# 619077  2006    40        3  MBG.DE      100.403022
# 619078  2006    40        4  MBG.DE      100.302264
#
# [619079 rows x 5 columns]

# %%
plot(x=Column.WEEKDAY, y=Column.PERCENT, data=df)
# Out:
#          Percent (mean)
# weekday
# 0                 100.0
# 1            100.119553
# 2            100.258177
# 3            100.312192
# 4            100.292831

# %% [markdown]
# ## Hourly stock price fluctuations with a day

# %%
from analysis import get_best_hour

df = get_best_hour(FILENAME, YahooRange.YEARS_2, limit=LIMIT)

df
# Out:
#         year  week  day  hour  Symbol  Percent (mean)
# 0       2020    48   23     8  G24.DE           100.0
# 1       2020    48   23     9  G24.DE        99.84436
# 2       2020    48   23    10  G24.DE       98.988324
# 3       2020    48   23    11  G24.DE        99.22179
# 4       2020    48   23    12  G24.DE        99.37743
# ...      ...   ...  ...   ...     ...             ...
# 710248  2022    46   17    16     LIN        99.79376
# 710249  2022    46   17    17     LIN      100.297234
# 710250  2022    46   17    18     LIN      100.195632
# 710251  2022    46   17    19     LIN       99.875647
# 710252  2022    46   17    20     LIN       99.757366
#
# [710253 rows x 6 columns]

# %%
plot(x=Column.HOUR, y=Column.PERCENT, data=df)
# Out:
#       Percent (mean)
# hour
# 6              100.0
# 7         100.001092
# 8          99.948331
# 9          99.935434
# 10         99.943173

# %% [markdown]
# ## Hourly and quarterly stock price fluctuations within a day

# %%
from analysis import get_best_time

df = get_best_time(FILENAME, YahooRange.DAYS_58, limit=LIMIT)

df
# Out:
#         year  week  day  hour  minute  time  Symbol  Percent (mean)
# 0       2022    38   21     7       0   7.0  ADJ.DE           100.0
# 1       2022    38   21     7      30   7.5  ADJ.DE        99.07251
# 2       2022    38   21     8       0   8.0  ADJ.DE        99.15683
# 3       2022    38   21     8      30   8.5  ADJ.DE       98.397982
# 4       2022    38   21     9       0   9.0  ADJ.DE       99.241151
# ...      ...   ...  ...   ...     ...   ...     ...             ...
# 107871  2022    46   16    18      30  18.5     LIN        99.88834
# 107872  2022    46   16    19       0  19.0     LIN       99.615886
# 107873  2022    46   16    19      30  19.5     LIN       99.846658
# 107874  2022    46   16    20       0  20.0     LIN       99.967251
# 107875  2022    46   16    20      30  20.5     LIN       99.752862
#
# [107876 rows x 8 columns]

# %%
# NOTE: filter extreme points, plot df first and if charts are bad try with fdf
fdf = df[df[Column.TIME].isin(np.arange(9, 16.5, 0.25))].copy()

plot(x=Column.TIME, y=Column.PERCENT, data=fdf)
# Out:
#       Percent (mean)
# time
# 9.0         99.92545
# 9.5         99.91161
# 10.0       99.924156
# 10.5       99.968054
# 11.0       99.967258

# %% [markdown]
# ## Quarterly stock price fluctuations within an hour

# %%
from analysis import get_best_quarter

df = get_best_quarter(FILENAME, YahooRange.DAYS_58, limit=LIMIT)

df
# Out:
#         year  week  day  hour  minute  quarter  Symbol  Percent (mean)
# 0       2022    38   21     7       0        0  ADJ.DE           100.0
# 1       2022    38   21     7      15       15  ADJ.DE      100.337274
# 2       2022    38   21     7      45       45  ADJ.DE        99.07251
# 3       2022    38   21     8       0        0  ADJ.DE           100.0
# 4       2022    38   21     8      15       15  ADJ.DE        99.57483
# ...      ...   ...  ...   ...     ...      ...     ...             ...
# 202745  2022    46   16    19      45       45     LIN      100.277992
# 202746  2022    46   16    20       0        0     LIN           100.0
# 202747  2022    46   16    20      15       15     LIN       99.729211
# 202748  2022    46   16    20      30       30     LIN       99.785542
# 202749  2022    46   16    20      45       45     LIN       99.830219
#
# [202750 rows x 8 columns]

# %%
plot(x=Column.QUARTER, y=Column.PERCENT, data=df)
# Out:
#          Percent (mean)
# quarter
# 0                 100.0
# 15           100.009535
# 30           100.019137
# 45           100.023944
